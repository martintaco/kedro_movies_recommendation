# %%
import json,os

# %%
variant_group = [
    {"200098620": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15309_07215.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Vinos", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate", "format_name": "Líquido", "tone": "VIN INTENSE", "size": "", "benefit": "Color", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261052003", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200098620", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "07215", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200098620", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200098620", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15309", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094745": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15264_03831.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Rojos", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "RED BELLE", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094745", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03831", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094745", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094745", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15264", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094744": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15275_03830.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Rojos", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "SCARLET ROUGE", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094744", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03830", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094744", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094744", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15275", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094736": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15262_03818.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Marrones", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "COPPER GOLD", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094736", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03818", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094736", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094736", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15262", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094737": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15265_03819.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Rosas", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "SUNSET ROSE", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094737", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03819", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094737", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094737", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15265", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094738": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15266_03821.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Vinos", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "BURGUNDY GLAZE", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094738", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03821", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094738", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094738", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15266", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094739": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15267_03822.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Marrones", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "METAL GOLD", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094739", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03822", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094739", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094739", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15267", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094740": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15259_03824.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Rosas", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "URBAN ROSE", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094740", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03824", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094740", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094740", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15259", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094741": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15260_03825.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Morados", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "ULTRA VIOLET", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094741", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03825", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094741", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094741", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15260", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094742": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15261_03827.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Fucsias", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "CERISE PASSION", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094742", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03827", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094742", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094742", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15261", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094744": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15275_03830.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Rojos", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "SCARLET ROUGE", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094744", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03830", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094744", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094744", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15275", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}},
    {"200094745": {"properties": {"name": "Infini Absolu Labial Líquido Larga Duración", "image_url": "https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15264_03831.jpg", "brand": "L'BEL", "description": "Labial Líquido de Larga Duración. 7 g e .24 oz.", "category_name": "MAQUILLAJE", "subcategory_name": "PARA LABIOS", "type_name": "LAPIZ LABIAL", "subtype_name": "LIQUIDO", "fragance_family": "", "gamma": "Rojos", "application_place_use": "Labios", "target_age": "", "finished_name": "Mate metálico", "format_name": "Líquido", "tone": "RED BELLE", "size": "", "benefit": "Larga Duracion", "presentation": "Sin Asignar", "net_content": "7.0", "unit_content": "G", "cod_generic_product": "P0261057008", "business_unit_name": "Cosmeticos", "keywords": "Infini Líquido, labial líquido, larga duración, labial líquido de larga duración", "color_rgb": "", "target_market": "Lapiz Labial", "concentration": "", "occasion": "", "recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094745", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0,  "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "03831", "cod_cuc": "P0261052003", "product_label_url": "", "line_name": "INFINI", "is_set": False, "main_product_sku": "200094745", "variant_group": "", "in_stock": True, "main_category": "Maquillaje", "product_price_b": 60.0, "product_saleprice_b": 42.0, "country": "PE", "channel": "MTO", "variant_group_data": ""}, "associations": {"category": {"categories": []}}, "overrides": {"region": {"PE_15": {"properties": {"recommendable": True, "link_url": "https://lbel.tiendabelcorp.com/pe/p/200094745", "price": 60.0, "sale_price": 42.0, "list_price_min": 60.0, "list_price_max": 60.0, "sale_price_min": 42.0, "sale_price_max": 42.0, "findable": True, "price_currency_iso": "PEN", "variants_type": "Color", "variant_default_code": "", "stock_level_status": "InStock", "is_variable_set": False, "place_holder_bundle_product_code": "", "picture_size_url": "", "picture_color_url": "", "main_cuv": "15264", "cod_cuc": "P0261052003", "product_label_url": "", "variant_group": "", "in_stock": True, "main_category": ""}}}, "sku": {}}}}
]

# %%
dict_to_edit = {"200094565":{"properties":{"name":"Infini Absolu Labial Líquido Larga Duración","image_url":"https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15317_05908.jpg","brand":"L'BEL","description":"Labial Líquido de Larga Duración. 7 g e .24 oz.","category_name":"MAQUILLAJE","subcategory_name":"PARA LABIOS","type_name":"LAPIZ LABIAL","subtype_name":"LIQUIDO","fragance_family":"","gamma":"Fucsias","application_place_use":"Labios","target_age":"","finished_name":"Mate","format_name":"Líquido","tone":"FUCSIA SEDUCTION","size":"","benefit":"Color","presentation":"Sin Asignar","net_content":"7.0","unit_content":"G","cod_generic_product":"P0261052003","business_unit_name":"Cosmeticos","keywords":"Infini Líquido, labial líquido, larga duración, labial líquido de larga duración","color_rgb":"","target_market":"Lapiz Labial","concentration":"","occasion":"","recommendable":True,"link_url":"https://lbel.tiendabelcorp.com/pe/p/200094565","price":60.0,"sale_price":42.0,"list_price_min":60.0,"list_price_max":60.0,"sale_price_min":42.0,"sale_price_max":42.0,"findable":True,"price_currency_iso":"PEN","variants_type":"Color","variant_default_code":"","stock_level_status":"InStock","is_variable_set":False,"place_holder_bundle_product_code":"","picture_size_url":"","picture_color_url":"","main_cuv":"05908","cod_cuc":"P0261052003","product_label_url":"","line_name":"INFINI","is_set":False,"main_product_sku":"200094565","variant_group":"","in_stock":True,"main_category":"Maquillaje","product_price_b":60.0,"product_saleprice_b":42.0,"country":"PE","channel":"MTO","variant_group_data":""},"associations":{"category":{"categories":[]}},"overrides":{"region":{"PE_15":{"properties":{"recommendable":True,"link_url":"https://lbel.tiendabelcorp.com/pe/p/200094565","price":60.0,"sale_price":42.0,"list_price_min":60.0,"list_price_max":60.0,"sale_price_min":42.0,"sale_price_max":42.0,"findable":True,"price_currency_iso":"PEN","variants_type":"Color","variant_default_code":"","stock_level_status":"InStock","is_variable_set":False,"place_holder_bundle_product_code":"","picture_size_url":"","picture_color_url":"","main_cuv":"15317","cod_cuc":"P0261052003","product_label_url":"","variant_group":"","in_stock":True,"main_category":""}}},"sku":{}}}}

# %%
def generate_variant_group_data_properties(data, key):
    variant_group_data = {
        "id": key,
        "name": data[key]['properties']['name'],
        "price": data[key]['properties']['price'],
        "sale_price": data[key]['properties']['sale_price'],
        "tone": data[key]['properties']['tone'],
        "color_rgb": data[key]['properties']['color_rgb'],
        "size": data[key]['properties']['size'],
        "stock_level_status": data[key]['properties']['stock_level_status'],
        "product_label_url": data[key]['properties']['product_label_url'],
        "picture_color_url": data[key]['properties']['picture_color_url'],
        "picture_size_url": data[key]['properties']['picture_size_url'],
        "image_url": data[key]['properties']['image_url'],
        "link_url": data[key]['properties']['link_url']
    }
    
    return json.dumps(variant_group_data)

def generate_variant_group_data_regions(data, key, region):
    variant_group_data = {
        "id": key,
        "name": data[key]['properties']['name'],
        "price": data[key]['overrides']['region'][region]['properties']['price'],
        "sale_price": data[key]['overrides']['region'][region]['properties']['sale_price'],
        "tone": data[key]['properties']['tone'],
        "color_rgb": data[key]['properties']['color_rgb'],
        "size": data[key]['properties']['size'],
        "stock_level_status": data[key]['overrides']['region'][region]['properties']['stock_level_status'],
        "product_label_url": data[key]['overrides']['region'][region]['properties']['product_label_url'],
        "picture_color_url": data[key]['overrides']['region'][region]['properties']['picture_color_url'],
        "picture_size_url": data[key]['overrides']['region'][region]['properties']['picture_size_url'],
        "image_url": data[key]['properties']['image_url'],
        "link_url": data[key]['properties']['link_url'].replace("/PE/",f"/{region.split('_')[0]}/")
    }
    
    return json.dumps(variant_group_data)
                                                            
def string_to_list(data, key, property_name):
    value = data[key]['properties'][property_name]
    property_list = list()
    property_list.append(value)
    
    return property_list

# %%
#Hard variables
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['strategy_code'] = '1'
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['product_price_b'] = dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['price']
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['product_saleprice_b'] = dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['sale_price']

dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['color_rgb'] = "#FF0000"
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['variants_type'] = "Color"
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['variant_default_code'] = list(dict_to_edit.keys())[0]

#List Variables
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['variant_group'] = list(set([list(product.keys())[0] for product in variant_group]))
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['gamma'] = list(set([product[list(product.keys())[0]]['properties']['gamma'] for product in variant_group]))
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['tone'] = list(set([product[list(product.keys())[0]]['properties']['tone'] for product in variant_group]))
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['variant_group_data'] = list(set([generate_variant_group_data_properties(product, list(product.keys())[0]) for product in variant_group]))

# %%
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['category_name'] = string_to_list(dict_to_edit, list(dict_to_edit.keys())[0], 'category_name')
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['subcategory_name'] = string_to_list(dict_to_edit, list(dict_to_edit.keys())[0], 'subcategory_name')
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['type_name'] = string_to_list(dict_to_edit, list(dict_to_edit.keys())[0], 'type_name')
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['subtype_name'] = string_to_list(dict_to_edit, list(dict_to_edit.keys())[0], 'subtype_name')
dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['line_name'] = string_to_list(dict_to_edit, list(dict_to_edit.keys())[0], 'line_name')

# %%
for key in dict_to_edit[list(dict_to_edit.keys())[0]]['overrides']['region'].keys():
    #Hard Variables
    dict_to_edit[list(dict_to_edit.keys())[0]]['overrides']['region'][key]['properties']['country'] = key.split('_')[0]
    if len(key.split('_'))>1:
        channel = 'MTO'
    else: 
        channel = 'ECOMM'
    dict_to_edit[list(dict_to_edit.keys())[0]]['overrides']['region'][key]['properties']['channel'] = channel 
    dict_to_edit[list(dict_to_edit.keys())[0]]['overrides']['region'][key]['properties']['main_category'] = dict_to_edit[list(dict_to_edit.keys())[0]]['properties']['category_name']
    dict_to_edit[list(dict_to_edit.keys())[0]]['overrides']['region'][key]['properties']['variants_type'] = "Color"
    dict_to_edit[list(dict_to_edit.keys())[0]]['overrides']['region'][key]['properties']['variant_default_code'] = list(dict_to_edit.keys())[0]
    
    #List Variables
    dict_to_edit[list(dict_to_edit.keys())[0]]['overrides']['region'][key]['properties']['variant_group'] = [list(product.keys())[0] for product in variant_group]
    dict_to_edit[list(dict_to_edit.keys())[0]]['overrides']['region'][key]['properties']['variant_group_data'] = [generate_variant_group_data_regions(product, list(product.keys())[0],key) for product in variant_group]

# %%
dict_to_edit
# Out:
# {'200094565': {'properties': {'name': 'Infini Absolu Labial Líquido Larga Duración',
#    'image_url': 'https://belc-linkedtactics-imagenes-qas.s3.amazonaws.com/lkt/cdi/images/PE/202015/PE_202015_1_15317_05908.jpg',
#    'brand': "L'BEL",
#    'description': 'Labial Líquido de Larga Duración. 7 g e .24 oz.',
#    'category_name': ['MAQUILLAJE'],
#    'subcategory_name': ['PARA LABIOS'],
#    'type_name': ['LAPIZ LABIAL'],
#    'subtype_name': ['LIQUIDO'],
#    'fragance_family': '',
#    'gamma': ['Rosas', 'Marrones', 'Fucsias', 'Morados', 'Vinos', 'Rojos'],
#    'application_place_use': 'Labios',
#    'target_age': '',
#    'finished_name': 'Mate',
#    'format_name': 'Líquido',
#    'tone': ['BURGUNDY GLAZE',
#     'CERISE PASSION',
#     'ULTRA VIOLET',
#     'VIN INTENSE',
#     'SCARLET ROUGE',
#     'URBAN ROSE',
#     'COPPER GOLD',
#     'SUNSET ROSE',
#     'RED BELLE',
#     'METAL GOLD'],
#    'size': '',
#    'benefit': 'Color',
#    'presentation': 'Sin Asignar',
# ...

# %%
with open('variant-group-file.json', 'w', encoding='utf-8') as outputfile:
    json.dump(dict_to_edit, outputfile, ensure_ascii=False)
    # #FFF988 rgb currentcy_iso
