# %%
import pandas as pd
import os

# %%
df = pd.read_parquet("rtl_dcliente")
df
# Out:
#        codpais       codcliente             nombre1 apellidopaterno  \
# 0           CO  000009900226610         HILDA MARIA            SOSA
# 1           CO  000000052114741       MARTHA STELLA        MARTINEZ
# 2           EC  000000005883776    GABRIELA LISBETH        MARTINEZ
# 3           PE  000000043170929     JENIFER TATIANA       RODRIGUEZ
# 4           CO  000009900228578             MORELIA         VERGARA
# ...        ...              ...                 ...             ...
# 118088      EC  000000001114085      MONICA YOLANDA        CARRILLO
# 118089      PE  000000034295591      BETSY VICTORIA           VALLE
# 118090      PE  000000043321528               NELIA         CABEZAS
# 118091      PE  000000074528743  ALEJANDRA PATRICIA          CAMPOS
# 118092      PE  000000043391720        KIARA GIMENA          QUISPE
#
#        apellidomaterno                                          direccion  \
# 0                 DIAZ        .    CR 116 A 66 62 EL PALMAR I Y II BOGOTA
# ...
