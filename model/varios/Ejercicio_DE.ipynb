# %% [markdown]
# # Ejercicios

# %% [markdown]
# Se tiene una información sobre el covid hasta el dia de ayer

# %%
import pandas as pd
df_covid19 = pd.read_json('https://pomber.github.io/covid19/timeseries.json')
df_covid19.head()
# Out:
#                                          Afghanistan  ...                                              Yemen
# 0  {'date': '2020-1-22', 'confirmed': 0, 'deaths'...  ...  {'date': '2020-1-22', 'confirmed': 0, 'deaths'...
# 1  {'date': '2020-1-23', 'confirmed': 0, 'deaths'...  ...  {'date': '2020-1-23', 'confirmed': 0, 'deaths'...
# 2  {'date': '2020-1-24', 'confirmed': 0, 'deaths'...  ...  {'date': '2020-1-24', 'confirmed': 0, 'deaths'...
# 3  {'date': '2020-1-25', 'confirmed': 0, 'deaths'...  ...  {'date': '2020-1-25', 'confirmed': 0, 'deaths'...
# 4  {'date': '2020-1-26', 'confirmed': 0, 'deaths'...  ...  {'date': '2020-1-26', 'confirmed': 0, 'deaths'...
#
# [5 rows x 185 columns]

# %% [markdown]
# **Se solicita el desarrollo, de estos 5 ejercicios**: (45min)

# %% [markdown]
# 1. Los 10 Paises (sobre la base total de paises) con mas casos confirmados con Coronavirus, y 10 con menos casos confirmados (2 datasets).

# %% [markdown]
# 2. Para el caso de China, listar la variación versus el dia anterior, en los ultimos 40 dias.

# %% [markdown]
# 3. Para el caso de Italia, en que dia se registro el mayor numero de muertes

# %% [markdown]
# 4. Para el caso de Francia, cual es el promedio de recuperados en la ultima semana

# %% [markdown]
# 5. Cuales son 5 directores del genero, que hayan trabajado con mas actores. considere la siguiente set de datos:  https://www.imdb.com/interfaces/
# El tipo de archivo gz es comprimido, el tipo de archivo  tsv es texto plano separado por tabuladores.
