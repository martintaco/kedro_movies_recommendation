# %% [markdown]
# **CLASE NRO 1**
#
# Esta es una clase de ejemplos:
#
# **Veremos algunos ejemplos con la función nativa print**

# %%
print('hola mundo')
# Out:
# hola mundo

# %%
print(5*2)
# Out:
# 10

# %%
print(2**3)
# Out:
# 8

# %%
print("Nombre:" + "Calamardo")
# Out:
# Nombre:Calamardo

# %%
print("Las","personas","se","han","vuelto","loco","con: \n","\t TikTok")
# Out:
# Las personas se han vuelto loco con:
#  	 TikTok

# %% [markdown]
# ## Tipos de Datos
#
# Los tipos de datos:
#
# ```
# Numericos:  123
# Booleanos:  True / False
# Cadenas: "Hola Mundo"
# Listas: [1,2,3,4,5]
# Tuplas: ['uno', 2, 3.0, False]
# Diccionario: {nombre:'José Álvaro', apellido: 'Osorio Balvin', fecha_nacimiento: '1985-05-07', nacionalidad:'Colombiano', profesion:'musica' }
# ```
#
# **Ahora veremos algunos ejemplo con variables**

# %%
m_int = 5
m_float = 2.4
m_bool = True
m_string = 'Domo 2020 big data'
m_list = [1,2,3,4,5]
m_tupla: ['uno', 2, 3.0, False]
m_diccionary = {'nombre':'José Álvaro', 'apellido':'Osorio Balvin', 'edad':35 ,'nacionalidad':'Colombiano', 'estatura': 1.7 }

# %%
m_result  = m_int*m_float  # El resultado lo almacenamos en otra varible
print(m_result, 'es del tipo', type(m_result))
# Out:
# 12.0 es del tipo <class 'float'>
