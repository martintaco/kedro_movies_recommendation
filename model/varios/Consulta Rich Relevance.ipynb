# %%
import pandas as pd 
import requests
import json
import urllib3
import os
from io import BytesIO
import gzip

# %%
endpoint = "https://gateway.richrelevance.com/streaming-view/v1/e1b75ced78fdfe64/683/product/?rows=1500"
headers = {"Authorization": "Bearer 36nIVy81NIvPxMfRboXvRJ5dSBsUiEK9"}

jsonAPI = requests.get(endpoint, headers=headers).json()

data = jsonAPI["items"]
print(jsonAPI["nextCursorMark"])
df = pd.json_normalize(data)
# Out:
# drclvgifgtuon

# %%
endpoint = "https://gateway.richrelevance.com/streaming-view/v1/e1b75ced78fdfe64/683/product/?rows=1500&nextCursorMark=drclvgifgtuon"
headers = {"Authorization": "Bearer 36nIVy81NIvPxMfRboXvRJ5dSBsUiEK9"}

jsonAPI1 = requests.get(endpoint, headers=headers).json()
data1 = jsonAPI1["items"]
print(jsonAPI1["nextCursorMark"])
df1 = pd.json_normalize(data1)
# Out:
# 3q6adtasp7kk4

# %%
endpoint = "https://gateway.richrelevance.com/streaming-view/v1/e1b75ced78fdfe64/683/product/?rows=1500&nextCursorMark=3q6adtasp7kk4"
headers = {"Authorization": "Bearer 36nIVy81NIvPxMfRboXvRJ5dSBsUiEK9"}

jsonAPI2 = requests.get(endpoint, headers=headers).json()
data2 = jsonAPI2["items"]
print(jsonAPI2["nextCursorMark"])
df2 = pd.json_normalize(data2)

# %%
df_product_region = df[['externalId','item.overrides.region.PE.properties.channel', 'item.overrides.region.PE.properties.price', 'item.overrides.region.PE.properties.in_stock', 'item.properties.name']]
print(df_product_region)
# Out:
#              externalId item.overrides.region.PE.properties.channel  \
# 0             210090480                                         NaN
# 1             210094342                                         NaN
# 2      2_2292_202112_co                                         NaN
# 3     2_12063_202114_cl                                         NaN
# 4             210097357                                       ECOMM
# ...                 ...                                         ...
# 1495          200105034                                       ECOMM
# 1496          200087985                                       ECOMM
# 1497          210096887                                       ECOMM
# 1498   2_3818_202113_co                                         NaN
# 1499  2_15161_202113_pe                                         NaN
#
#       item.overrides.region.PE.properties.price  \
# 0                                           NaN
# 1                                           NaN
# ...

# %%
df_final = df_product_region[(df_product_region['item.overrides.region.PE.properties.channel'] == "ECOMM")]
df_final
# Out:
#      externalId item.overrides.region.PE.properties.channel  \
# 4     210097357                                       ECOMM
# 7     210095299                                       ECOMM
# 9     200107204                                       ECOMM
# 10    210097912                                       ECOMM
# 11    210097302                                       ECOMM
# ...         ...                                         ...
# 1492  210096144                                       ECOMM
# 1494  210095205                                       ECOMM
# 1495  200105034                                       ECOMM
# 1496  200087985                                       ECOMM
# 1497  210096887                                       ECOMM
#
#       item.overrides.region.PE.properties.price  \
# 4                                          60.0
# 7                                         105.0
# 9                                         104.0
# ...
